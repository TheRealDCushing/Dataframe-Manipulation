# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %%
player_count_summary_as_dataframe = pd.DataFrame({
    'Total Players' : [576]
})
player_count_summary_as_dataframe
# Out:
#    Total Players
# 0            576

# %%
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_item_count = len(df['Item ID'].unique())
average_price_of_items = round(float(df['Price'].mean()), 2)
count_of_purchases = len(df['Price'])
price_sum = float(df['Price'].sum())
price_sum

summary_dataframe = pd.DataFrame({
    'Number of Unique Items': [unique_item_count],
    'Average Price': '$' + str(average_price_of_items),
    'Number of Purchases': [count_of_purchases],
    'Total Revenue': '$' + str(price_sum)
})


summary_dataframe
# Out:
#    Number of Unique Items Average Price  Number of Purchases Total Revenue
# 0                     183         $3.05                  780      $2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
df_gender1 = df[['Gender','SN']].drop_duplicates(subset = 'SN')

gender_count = df_gender1['Gender'].value_counts(0)
gender_percent = df_gender1['Gender'].value_counts(1)

gender_count_df = pd.DataFrame(gender_count)
gender_percent_df = round(pd.DataFrame(gender_percent) * 100, 2)

gender_summary_df = gender_count_df.merge(gender_percent_df, left_index = True, right_index = True)
gender_summary_df.columns = ['Total Count', 'Percentage of Players']
gender_summary_df
# Out:
#                        Total Count  Percentage of Players
# Male                           484                  84.03
# Female                          81                  14.06
# Other / Non-Disclosed           11                   1.91

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
df_gender_2 = df.groupby('Gender')

purchase_count = round(df_gender_2['Purchase ID'].count(), 0)
avg_purchase_price = round(df_gender_2['Price'].mean(), 2)
total_purchase_value = round(df_gender_2['Price'].sum(), 2)
purchase_value_per_gender = round(total_purchase_value / gender_count, 2)

summary_dataframe2 = pd.DataFrame([purchase_count, avg_purchase_price, total_purchase_value, purchase_value_per_gender])
summary2 = summary_dataframe2.T
summary2.columns = ['Purchase Count', 'Average Purchase Price', 'Total Purchase Value', 'Avg Total Purchase per Person']
summary2
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                          113.0                    3.20
# Male                            652.0                    3.02
# Other / Non-Disclosed            15.0                    3.35
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Gender
# Female                               361.94                           4.47
# Male                                1967.64                           4.07
# Other / Non-Disclosed                 50.19                           4.56

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [0, 9, 14, 19, 24, 29, 34, 39, 150]
bin_labels = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']

df["Total Count"] = pd.cut(df["Age"], bins, labels=bin_labels)
df_age1 = df[['Total Count','SN']].drop_duplicates(subset = 'SN')

age_demographics_summary = df_age1.groupby("Total Count").count()
age_counts = age_demographics_summary['SN']
age_demographics_percentages = round(age_counts / 576 * 100, 2)
age_demographics_percentages

summary_dataframe3 = pd.DataFrame([age_counts, age_demographics_percentages])

summary_data = summary_dataframe3.T

summary_data.columns = ['Total Count', 'Percentage of Players']

summary_data
# Out:
#              Total Count  Percentage of Players
# Total Count
# <10                 17.0                   2.95
# 10-14               22.0                   3.82
# 15-19              107.0                  18.58
# 20-24              258.0                  44.79
# 25-29               77.0                  13.37
# 30-34               52.0                   9.03
# 35-39               31.0                   5.38
# 40+                 12.0                   2.08

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
bins = [0, 9, 14, 19, 24, 29, 34, 39, 150]
bin_labels = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']

df["Total Count"] = pd.cut(df["Age"], bins, labels=bin_labels)
less_rows = df[['Total Count','SN', 'Price']]

less_rows_grouped = less_rows.groupby('Total Count')
purchase_counts = less_rows_grouped['Price'].count()
average_prices = round(less_rows_grouped['Price'].mean(),2)
total_spent = round(less_rows_grouped['Price'].sum(), 2)
spending_per_person = round(total_spent/age_counts,2)


summary4 = pd.DataFrame([purchase_counts, average_prices, total_spent, spending_per_person])
summary4b = summary4.T
summary4b.columns = ['Purchase Count', 'Average Purchase Price', 'Total Purchase Value', 'Avg Total Purchase per Person']
summary4b
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value  \
# Total Count
# <10                    23.0                    3.35                 77.13
# 10-14                  28.0                    2.96                 82.78
# 15-19                 136.0                    3.04                412.89
# 20-24                 365.0                    3.05               1114.06
# 25-29                 101.0                    2.90                293.00
# 30-34                  73.0                    2.93                214.00
# 35-39                  41.0                    3.60                147.67
# 40+                    13.0                    2.94                 38.24
#
#              Avg Total Purchase per Person
# Total Count
# <10                                   4.54
# 10-14                                 3.76
# 15-19                                 3.86
# 20-24                                 4.32
# 25-29                                 3.81
# 30-34                                 4.12
# 35-39                                 4.76
# 40+                                   3.19

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
df_sn_2 = df.groupby('SN')
purchase_counts = df_sn_2['Gender'].count()
average_spending = round(df_sn_2['Price'].mean(),2)
total_purchase = round(df_sn_2['Price'].sum(),2)

summary6 = pd.DataFrame([purchase_counts, average_spending, total_purchase])
summary7 = summary6.T
summary7.columns = ['Purchase Count', 'Average Purchase Price', 'Total Purchase Value']
summary7.sort_values('Total Purchase Value', ascending=False).reset_index()
# Out:
#                 SN  Purchase Count  Average Purchase Price  \
# 0        Lisosia93             5.0                    3.79
# 1      Idastidru52             4.0                    3.86
# 2       Chamjask73             3.0                    4.61
# 3           Iral74             4.0                    3.40
# 4      Iskadarya95             3.0                    4.37
# 5         Ilarin91             3.0                    4.23
# 6        Ialallo29             3.0                    3.95
# 7        Tyidaim51             3.0                    3.94
# 8     Lassilsala30             3.0                    3.84
# 9      Chadolyla44             3.0                    3.82
# 10           Iri67             3.0                    3.79
# 11       Inguron55             3.0                    3.70
# 12     Siallylis44             3.0                    3.46
# 13    Saistyphos30             3.0                    3.44
# 14        Phyali88             3.0                    3.43
# 15     Strithenu87             3.0                    3.39
# 16         Lisim78             3.0                    3.34
# 17    Haillyrgue51             3.0                    3.17
# 18       Phistym51             2.0                    4.75
# 19         Lamil79             2.0                    4.64
# 20          Aina42             3.0                    3.07
# 21     Saesrideu94             2.0                    4.59
# 22          Arin32             2.0                    4.54
# 23       Rarallo90             3.0                    3.02
# 24   Baelollodeu94             2.0                    4.51
# 25         Aelin32             3.0                    2.99
# 26      Lisopela58             3.0                    2.95
# 27    Saedaiphos46             3.0                    2.94
# 28       Reunasu60             2.0                    4.41
# 29    Chanastnya43             3.0                    2.94
# ..             ...             ...                     ...
# 546       Lirtim36             1.0                    1.33
# 547       Shidai42             1.0                    1.33
# 548     Philodil43             1.0                    1.29
# 549       Eyista89             1.0                    1.29
# 550     Mindilsa60             1.0                    1.28
# 551     Tyarithn67             1.0                    1.14
# 552        Aisur51             1.0                    1.14
# 553       Ilista82             1.0                    1.14
# 554    Jiskimsda56             1.0                    1.14
# 555  Aillyriadru65             1.0                    1.10
# 556        Eryon48             1.0                    1.10
# 557      Iduelis31             1.0                    1.10
# 558        Yasur85             1.0                    1.10
# 559      Undjask33             1.0                    1.10
# 560     Lirtassa52             1.0                    1.09
# 561      Aelidru27             1.0                    1.09
# 562     Yalaeria91             1.0                    1.06
# 563  Aesurstilis64             1.0                    1.03
# 564        Saida58             1.0                    1.03
# 565        Euthe35             1.0                    1.03
# 566         Hala31             1.0                    1.02
# 567    Qilalista41             1.0                    1.02
# 568  Frichjaskan98             1.0                    1.02
# 569      Isurria36             1.0                    1.02
# 570       Eudanu84             1.0                    1.02
# 571    Ililsasya43             1.0                    1.02
# 572       Irilis75             1.0                    1.02
# 573        Aidai61             1.0                    1.01
# 574     Chanirra79             1.0                    1.01
# 575          Alo38             1.0                    1.00
#
#      Total Purchase Value
# 0                   18.96
# 1                   15.45
# 2                   13.83
# 3                   13.62
# 4                   13.10
# 5                   12.70
# 6                   11.84
# 7                   11.83
# 8                   11.51
# 9                   11.46
# 10                  11.37
# 11                  11.11
# 12                  10.37
# 13                  10.33
# 14                  10.30
# 15                  10.18
# 16                  10.02
# 17                   9.50
# 18                   9.50
# 19                   9.29
# 20                   9.22
# 21                   9.18
# 22                   9.09
# 23                   9.05
# 24                   9.03
# 25                   8.98
# 26                   8.86
# 27                   8.83
# 28                   8.82
# 29                   8.82
# ..                    ...
# 546                  1.33
# 547                  1.33
# 548                  1.29
# 549                  1.29
# 550                  1.28
# 551                  1.14
# 552                  1.14
# 553                  1.14
# 554                  1.14
# 555                  1.10
# 556                  1.10
# 557                  1.10
# 558                  1.10
# 559                  1.10
# 560                  1.09
# 561                  1.09
# 562                  1.06
# 563                  1.03
# 564                  1.03
# 565                  1.03
# 566                  1.02
# 567                  1.02
# 568                  1.02
# 569                  1.02
# 570                  1.02
# 571                  1.02
# 572                  1.02
# 573                  1.01
# 574                  1.01
# 575                  1.00
#
# [576 rows x 4 columns]

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
df_sn_3 = df.groupby(['Item ID', 'Item Name'])
purchase_counts2 = df_sn_3['Gender'].count()
average_spending2 = round(df_sn_3['Price'].mean(),2)
total_purchase2 = round(df_sn_3['Price'].sum(),2)

summary7 = pd.DataFrame([purchase_counts2, average_spending2, total_purchase2])
summary8 = summary7.T
summary8.columns = ['Purchase Count', 'Item Price', 'Total Purchase Value']
summary8.sort_values('Purchase Count', ascending=False)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm            12.0
# 145     Fiery Glass Crusader                                     9.0
# 108     Extraction, Quickblade Of Trembling Hands                9.0
# 82      Nirvana                                                  9.0
# 19      Pursuit, Cudgel of Necromancy                            8.0
# 103     Singed Scalpel                                           8.0
# 75      Brutality Ivory Warmace                                  8.0
# 72      Winter's Bite                                            8.0
# 60      Wolf                                                     8.0
# 59      Lightning, Etcher of the King                            8.0
# 37      Shadow Strike, Glory of Ending Hope                      8.0
# 34      Retribution Axe                                          8.0
# 92      Final Critic                                             8.0
# 53      Vengeance Cleaver                                        7.0
# 110     Suspension                                               7.0
# 7       Thorn, Satchel of Dark Souls                             7.0
# 71      Demise                                                   7.0
# 117     Heartstriker, Legacy of the Light                        7.0
# 159     Oathbreaker, Spellblade of Trials                        7.0
# 85      Malificent Bag                                           7.0
# 164     Exiled Doomblade                                         7.0
# 141     Persuasion                                               7.0
# 78      Glimmer, Ender of the Moon                               7.0
# 102     Avenger                                                  6.0
# 129     Fate, Vengeance of Eternal Justice                       6.0
# 93      Apocalyptic Battlescythe                                 6.0
# 54      Eternal Cleaver                                          6.0
# 3       Phantomlight                                             6.0
# 2       Verdict                                                  6.0
# 40      Second Chance                                            6.0
# ...                                                              ...
# 81      Dreamkiss                                                2.0
# 6       Rusty Skull                                              2.0
# 18      Torchlight, Bond of Storms                               2.0
# 26      Unholy Wand                                              2.0
# 28      Flux, Destroyer of Due Diligence                         2.0
# 30      Stormcaller                                              2.0
# 158     Darkheart, Butcher of the Champion                       2.0
# 69      Frenzy, Defender of the Harvest                          2.0
# 132     Persuasion                                               2.0
# 63      Stormfury Mace                                           2.0
# 56      Foul Titanium Battle Axe                                 2.0
# 127     Heartseeker, Reaver of Souls                             2.0
# 48      Rage, Legacy of the Lone Victor                          2.0
# 125     Whistling Mithril Warblade                               2.0
# 43      Foul Edge                                                2.0
# 115     Spectral Diamond Doomblade                               2.0
# 33      Curved Axe                                               2.0
# 31      Trickster                                                2.0
# 118     Ghost Reaver, Longsword of Magic                         1.0
# 47      Alpha, Reach of Ending Hope                              1.0
# 42      The Decapitator                                          1.0
# 27      Riddle, Tribute of Ended Dreams                          1.0
# 126     Exiled Mithril Longsword                                 1.0
# 51      Endbringer                                               1.0
# 90      Betrayer                                                 1.0
# 104     Gladiator's Glaive                                       1.0
# 23      Crucifer                                                 1.0
# 180     Stormcaller                                              1.0
# 91      Celeste                                                  1.0
# 134     Undead Crusader                                          1.0
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 145     Fiery Glass Crusader                                4.58
# 108     Extraction, Quickblade Of Trembling Hands           3.53
# 82      Nirvana                                             4.90
# 19      Pursuit, Cudgel of Necromancy                       1.02
# 103     Singed Scalpel                                      4.35
# 75      Brutality Ivory Warmace                             2.42
# 72      Winter's Bite                                       3.77
# 60      Wolf                                                3.54
# 59      Lightning, Etcher of the King                       4.23
# 37      Shadow Strike, Glory of Ending Hope                 3.16
# 34      Retribution Axe                                     2.22
# 92      Final Critic                                        4.88
# 53      Vengeance Cleaver                                   2.05
# 110     Suspension                                          1.44
# 7       Thorn, Satchel of Dark Souls                        1.33
# 71      Demise                                              1.61
# 117     Heartstriker, Legacy of the Light                   1.79
# 159     Oathbreaker, Spellblade of Trials                   3.08
# 85      Malificent Bag                                      1.75
# 164     Exiled Doomblade                                    1.63
# 141     Persuasion                                          3.19
# 78      Glimmer, Ender of the Moon                          4.40
# 102     Avenger                                             3.44
# 129     Fate, Vengeance of Eternal Justice                  1.54
# 93      Apocalyptic Battlescythe                            1.97
# 54      Eternal Cleaver                                     2.50
# 3       Phantomlight                                        2.49
# 2       Verdict                                             2.48
# 40      Second Chance                                       2.52
# ...                                                          ...
# 81      Dreamkiss                                           3.61
# 6       Rusty Skull                                         3.70
# 18      Torchlight, Bond of Storms                          4.65
# 26      Unholy Wand                                         1.12
# 28      Flux, Destroyer of Due Diligence                    1.06
# 30      Stormcaller                                         2.21
# 158     Darkheart, Butcher of the Champion                  2.45
# 69      Frenzy, Defender of the Harvest                     1.98
# 132     Persuasion                                          3.33
# 63      Stormfury Mace                                      4.99
# 56      Foul Titanium Battle Axe                            2.92
# 127     Heartseeker, Reaver of Souls                        3.92
# 48      Rage, Legacy of the Lone Victor                     2.48
# 125     Whistling Mithril Warblade                          1.00
# 43      Foul Edge                                           3.54
# 115     Spectral Diamond Doomblade                          2.04
# 33      Curved Axe                                          1.16
# 31      Trickster                                           1.55
# 118     Ghost Reaver, Longsword of Magic                    2.17
# 47      Alpha, Reach of Ending Hope                         3.58
# 42      The Decapitator                                     1.75
# 27      Riddle, Tribute of Ended Dreams                     3.30
# 126     Exiled Mithril Longsword                            2.00
# 51      Endbringer                                          4.66
# 90      Betrayer                                            2.94
# 104     Gladiator's Glaive                                  1.93
# 23      Crucifer                                            1.99
# 180     Stormcaller                                         3.36
# 91      Celeste                                             4.17
# 134     Undead Crusader                                     4.50
#
#                                                       Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                 50.76
# 145     Fiery Glass Crusader                                         41.22
# 108     Extraction, Quickblade Of Trembling Hands                    31.77
# 82      Nirvana                                                      44.10
# 19      Pursuit, Cudgel of Necromancy                                 8.16
# 103     Singed Scalpel                                               34.80
# 75      Brutality Ivory Warmace                                      19.36
# 72      Winter's Bite                                                30.16
# 60      Wolf                                                         28.32
# 59      Lightning, Etcher of the King                                33.84
# 37      Shadow Strike, Glory of Ending Hope                          25.28
# 34      Retribution Axe                                              17.76
# 92      Final Critic                                                 39.04
# 53      Vengeance Cleaver                                            14.35
# 110     Suspension                                                   10.08
# 7       Thorn, Satchel of Dark Souls                                  9.31
# 71      Demise                                                       11.27
# 117     Heartstriker, Legacy of the Light                            12.53
# 159     Oathbreaker, Spellblade of Trials                            21.56
# 85      Malificent Bag                                               12.25
# 164     Exiled Doomblade                                             11.41
# 141     Persuasion                                                   22.33
# 78      Glimmer, Ender of the Moon                                   30.80
# 102     Avenger                                                      20.64
# 129     Fate, Vengeance of Eternal Justice                            9.24
# 93      Apocalyptic Battlescythe                                     11.82
# 54      Eternal Cleaver                                              15.00
# 3       Phantomlight                                                 14.94
# 2       Verdict                                                      14.88
# 40      Second Chance                                                15.12
# ...                                                                    ...
# 81      Dreamkiss                                                     7.22
# 6       Rusty Skull                                                   7.40
# 18      Torchlight, Bond of Storms                                    9.30
# 26      Unholy Wand                                                   2.24
# 28      Flux, Destroyer of Due Diligence                              2.12
# 30      Stormcaller                                                   4.42
# 158     Darkheart, Butcher of the Champion                            4.90
# 69      Frenzy, Defender of the Harvest                               3.96
# 132     Persuasion                                                    6.66
# 63      Stormfury Mace                                                9.98
# 56      Foul Titanium Battle Axe                                      5.84
# 127     Heartseeker, Reaver of Souls                                  7.84
# 48      Rage, Legacy of the Lone Victor                               4.96
# 125     Whistling Mithril Warblade                                    2.00
# 43      Foul Edge                                                     7.08
# 115     Spectral Diamond Doomblade                                    4.08
# 33      Curved Axe                                                    2.32
# 31      Trickster                                                     3.10
# 118     Ghost Reaver, Longsword of Magic                              2.17
# 47      Alpha, Reach of Ending Hope                                   3.58
# 42      The Decapitator                                               1.75
# 27      Riddle, Tribute of Ended Dreams                               3.30
# 126     Exiled Mithril Longsword                                      2.00
# 51      Endbringer                                                    4.66
# 90      Betrayer                                                      2.94
# 104     Gladiator's Glaive                                            1.93
# 23      Crucifer                                                      1.99
# 180     Stormcaller                                                   3.36
# 91      Celeste                                                       4.17
# 134     Undead Crusader                                               4.50
#
# [183 rows x 3 columns]

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
summary8.sort_values('Total Purchase Value', ascending=False)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm            12.0
# 82      Nirvana                                                  9.0
# 145     Fiery Glass Crusader                                     9.0
# 92      Final Critic                                             8.0
# 103     Singed Scalpel                                           8.0
# 59      Lightning, Etcher of the King                            8.0
# 108     Extraction, Quickblade Of Trembling Hands                9.0
# 78      Glimmer, Ender of the Moon                               7.0
# 72      Winter's Bite                                            8.0
# 60      Wolf                                                     8.0
# 179     Wolf, Promise of the Moonwalker                          6.0
# 160     Azurewrath                                               6.0
# 25      Hero Cane                                                6.0
# 37      Shadow Strike, Glory of Ending Hope                      8.0
# 139     Mercy, Katana of Dismay                                  5.0
# 128     Blazeguard, Reach of Eternity                            5.0
# 138     Peacekeeper, Wit of Dark Magic                           5.0
# 141     Persuasion                                               7.0
# 87      Deluge, Edge of the West                                 5.0
# 159     Oathbreaker, Spellblade of Trials                        7.0
# 136     Ghastly Adamantite Protector                             6.0
# 65      Conqueror Adamantite Mace                                5.0
# 101     Final Critic                                             5.0
# 102     Avenger                                                  6.0
# 133     Faith's Scimitar                                         5.0
# 39      Betrayal, Whisper of Grieving Widows                     5.0
# 111     Misery's End                                             4.0
# 165     Bone Crushing Silver Skewer                              4.0
# 75      Brutality Ivory Warmace                                  8.0
# 52      Hatred                                                   4.0
# ...                                                              ...
# 124     Venom Claymore                                           4.0
# 0       Splinter                                                 4.0
# 155     War-Forged Gold Deflector                                5.0
# 48      Rage, Legacy of the Lone Victor                          2.0
# 158     Darkheart, Butcher of the Champion                       2.0
# 51      Endbringer                                               1.0
# 134     Undead Crusader                                          1.0
# 30      Stormcaller                                              2.0
# 135     Warped Diamond Crusader                                  3.0
# 91      Celeste                                                  1.0
# 177     Winterthorn, Defender of Shifting Worlds                 2.0
# 70      Hope's End                                               4.0
# 115     Spectral Diamond Doomblade                               2.0
# 69      Frenzy, Defender of the Harvest                          2.0
# 47      Alpha, Reach of Ending Hope                              1.0
# 180     Stormcaller                                              1.0
# 27      Riddle, Tribute of Ended Dreams                          1.0
# 183     Dragon's Greatsword                                      3.0
# 31      Trickster                                                2.0
# 168     Sun Strike, Jaws of Twisted Visions                      2.0
# 90      Betrayer                                                 1.0
# 33      Curved Axe                                               2.0
# 26      Unholy Wand                                              2.0
# 118     Ghost Reaver, Longsword of Magic                         1.0
# 28      Flux, Destroyer of Due Diligence                         2.0
# 125     Whistling Mithril Warblade                               2.0
# 126     Exiled Mithril Longsword                                 1.0
# 23      Crucifer                                                 1.0
# 104     Gladiator's Glaive                                       1.0
# 42      The Decapitator                                          1.0
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 82      Nirvana                                             4.90
# 145     Fiery Glass Crusader                                4.58
# 92      Final Critic                                        4.88
# 103     Singed Scalpel                                      4.35
# 59      Lightning, Etcher of the King                       4.23
# 108     Extraction, Quickblade Of Trembling Hands           3.53
# 78      Glimmer, Ender of the Moon                          4.40
# 72      Winter's Bite                                       3.77
# 60      Wolf                                                3.54
# 179     Wolf, Promise of the Moonwalker                     4.48
# 160     Azurewrath                                          4.40
# 25      Hero Cane                                           4.35
# 37      Shadow Strike, Glory of Ending Hope                 3.16
# 139     Mercy, Katana of Dismay                             4.94
# 128     Blazeguard, Reach of Eternity                       4.91
# 138     Peacekeeper, Wit of Dark Magic                      4.74
# 141     Persuasion                                          3.19
# 87      Deluge, Edge of the West                            4.43
# 159     Oathbreaker, Spellblade of Trials                   3.08
# 136     Ghastly Adamantite Protector                        3.58
# 65      Conqueror Adamantite Mace                           4.24
# 101     Final Critic                                        4.19
# 102     Avenger                                             3.44
# 133     Faith's Scimitar                                    4.09
# 39      Betrayal, Whisper of Grieving Widows                3.94
# 111     Misery's End                                        4.89
# 165     Bone Crushing Silver Skewer                         4.86
# 75      Brutality Ivory Warmace                             2.42
# 52      Hatred                                              4.84
# ...                                                          ...
# 124     Venom Claymore                                      1.29
# 0       Splinter                                            1.28
# 155     War-Forged Gold Deflector                           1.01
# 48      Rage, Legacy of the Lone Victor                     2.48
# 158     Darkheart, Butcher of the Champion                  2.45
# 51      Endbringer                                          4.66
# 134     Undead Crusader                                     4.50
# 30      Stormcaller                                         2.21
# 135     Warped Diamond Crusader                             1.40
# 91      Celeste                                             4.17
# 177     Winterthorn, Defender of Shifting Worlds            2.08
# 70      Hope's End                                          1.03
# 115     Spectral Diamond Doomblade                          2.04
# 69      Frenzy, Defender of the Harvest                     1.98
# 47      Alpha, Reach of Ending Hope                         3.58
# 180     Stormcaller                                         3.36
# 27      Riddle, Tribute of Ended Dreams                     3.30
# 183     Dragon's Greatsword                                 1.09
# 31      Trickster                                           1.55
# 168     Sun Strike, Jaws of Twisted Visions                 1.48
# 90      Betrayer                                            2.94
# 33      Curved Axe                                          1.16
# 26      Unholy Wand                                         1.12
# 118     Ghost Reaver, Longsword of Magic                    2.17
# 28      Flux, Destroyer of Due Diligence                    1.06
# 125     Whistling Mithril Warblade                          1.00
# 126     Exiled Mithril Longsword                            2.00
# 23      Crucifer                                            1.99
# 104     Gladiator's Glaive                                  1.93
# 42      The Decapitator                                     1.75
#
#                                                       Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                 50.76
# 82      Nirvana                                                      44.10
# 145     Fiery Glass Crusader                                         41.22
# 92      Final Critic                                                 39.04
# 103     Singed Scalpel                                               34.80
# 59      Lightning, Etcher of the King                                33.84
# 108     Extraction, Quickblade Of Trembling Hands                    31.77
# 78      Glimmer, Ender of the Moon                                   30.80
# 72      Winter's Bite                                                30.16
# 60      Wolf                                                         28.32
# 179     Wolf, Promise of the Moonwalker                              26.88
# 160     Azurewrath                                                   26.40
# 25      Hero Cane                                                    26.10
# 37      Shadow Strike, Glory of Ending Hope                          25.28
# 139     Mercy, Katana of Dismay                                      24.70
# 128     Blazeguard, Reach of Eternity                                24.55
# 138     Peacekeeper, Wit of Dark Magic                               23.70
# 141     Persuasion                                                   22.33
# 87      Deluge, Edge of the West                                     22.15
# 159     Oathbreaker, Spellblade of Trials                            21.56
# 136     Ghastly Adamantite Protector                                 21.48
# 65      Conqueror Adamantite Mace                                    21.20
# 101     Final Critic                                                 20.95
# 102     Avenger                                                      20.64
# 133     Faith's Scimitar                                             20.45
# 39      Betrayal, Whisper of Grieving Widows                         19.70
# 111     Misery's End                                                 19.56
# 165     Bone Crushing Silver Skewer                                  19.44
# 75      Brutality Ivory Warmace                                      19.36
# 52      Hatred                                                       19.36
# ...                                                                    ...
# 124     Venom Claymore                                                5.16
# 0       Splinter                                                      5.12
# 155     War-Forged Gold Deflector                                     5.05
# 48      Rage, Legacy of the Lone Victor                               4.96
# 158     Darkheart, Butcher of the Champion                            4.90
# 51      Endbringer                                                    4.66
# 134     Undead Crusader                                               4.50
# 30      Stormcaller                                                   4.42
# 135     Warped Diamond Crusader                                       4.20
# 91      Celeste                                                       4.17
# 177     Winterthorn, Defender of Shifting Worlds                      4.16
# 70      Hope's End                                                    4.12
# 115     Spectral Diamond Doomblade                                    4.08
# 69      Frenzy, Defender of the Harvest                               3.96
# 47      Alpha, Reach of Ending Hope                                   3.58
# 180     Stormcaller                                                   3.36
# 27      Riddle, Tribute of Ended Dreams                               3.30
# 183     Dragon's Greatsword                                           3.27
# 31      Trickster                                                     3.10
# 168     Sun Strike, Jaws of Twisted Visions                           2.96
# 90      Betrayer                                                      2.94
# 33      Curved Axe                                                    2.32
# 26      Unholy Wand                                                   2.24
# 118     Ghost Reaver, Longsword of Magic                              2.17
# 28      Flux, Destroyer of Due Diligence                              2.12
# 125     Whistling Mithril Warblade                                    2.00
# 126     Exiled Mithril Longsword                                      2.00
# 23      Crucifer                                                      1.99
# 104     Gladiator's Glaive                                            1.93
# 42      The Decapitator                                               1.75
#
# [183 rows x 3 columns]
